# %%
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy
import scipy

# %% [markdown]
# Vesicularity = -0.0014*D2 -0.0216*D+.7415

# %%
# clear previous data
# %reset -f
# run flowgo for /path/to/input_file.json
#%run -i main_flowgo.py ./resource/etna_bl_Bingham.json

# %run -i main_flowgo.py resource/Fissure8_jul27_POLY_RIGID2.json
#%run -i main_flowgo.py resource/James_F8.json
# Out:
# effusion_rate =1500.3570775237265
# channel_depth =8.918999999999992
# Vmean (m/s)= 8.853701308995744
# effusion_rate =1500.3570775237265
# distance from vent (m) = 0.0
# phi= 0.12705704083939273
# Tcore= 1423.0792693591532
# Vmean (m/s)= 8.379294687930862
# distance from vent (m) = 10.0
# phi= 0.12711280761419452
# Tcore= 1423.010118558399
# Vmean (m/s)= 8.380249399306773
# distance from vent (m) = 20.0
# phi= 0.127166275134164
# Tcore= 1422.943818833637
# Vmean (m/s)= 6.983642155135473
# distance from vent (m) = 30.0
# phi= 0.12722778911450827
# Tcore= 1422.86754149801
# Vmean (m/s)= 6.654485084012391
# distance from vent (m) = 40.0
# phi= 0.12729050901855718
# Tcore= 1422.7897688169894
# Vmean (m/s)= 6.3930344386168425
# distance from vent (m) = 50.0
# phi= 0.12735428161625978
# Tcore= 1422.7106907958382
# Vmean (m/s)= 6.13143380155051
# distance from vent (m) = 60.0
# phi= 0.12741944412122203
# Tcore= 1422.629889289685
# Vmean (m/s)= 5.86965016015404
# ...

# %%
# some basic plotting to compare different results

# %run -i compare_results.py ./results2/results_ [Fissure8_Poly_Rigid2_10.0m] "Rheology Comparison" 0



#%run -i compare_results.py ./results2/results_ [fissure8_jul27_10.0m_RIGID_Poly] "Rheology Comparison" 0
#%run -i compare_results.py ./results2/results_ [james_fissure8_10.0m] "Rheology Comparison" 0
# Out:
# Max distance is 11930.0

# %%
#plot distance

# %%
# some basic plotting to compare different results
#%run -i compare_results.py ./results/results_ [etna_er_10.0m,etna_ptp1_10.0m,etna_bl_10.0m,etna_bl_Bingham_10.0m] "Rheology Comparison" 0

# %%
#%run -i compare_results_custom.py ./results/results_ [ER,PTP1,This_study,This_study_n=1] "Rheology Comparison" '1,2'
